# %%
import matplotlib.pyplot as plt
import os
from localizer import *

# %%
# load pretrained_model
# For plain detecotr model "plain_detecotr.pkl"
pretrain_model = "0708.pkl"
model = hand_localizer()
if pretrain_model in os.listdir('./models/'):
    model.handDetector = pickle.load(gzip.open('./models/'+pretrain_model, 'rb'))
else:
    # trains images from ./dataset/user_X/imgs.jpg with labels inside ./dataset/user/user_X.csv 
    model.train()
model.evaluate("./results/fisheye_detector/test_data")
model.save("0708.pkl")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d0ff8342355c> in <module>
#       2 # For plain detecotr model "plain_detecotr.pkl"
#       3 pretrain_model = "0708.pkl"
# ----> 4 model = hand_localizer()
#       5 if pretrain_model in os.listdir('./models/'):
#       6     model.handDetector = pickle.load(gzip.open('./models/'+pretrain_model, 'rb'))
#
# NameError: name 'hand_localizer' is not defined

# %% [markdown]
# ### Test Dataset

# %%
for i, image in enumerate(os.listdir('./dataset/test_data')):
    img = plt.imread('./dataset/test_data/' + image)
    plt.figure(i, figsize=(4,4))
    plt.imshow(img)
    plt.show()

# %% [markdown]
# ### Plain Hand Detector Result

# %%
for i, image in enumerate(os.listdir('./results/plain_detector/test_data_side250')):
    img = plt.imread('./results/plain_detector/test_data_side250/' + image)
    plt.figure(i, figsize=(4,4))
    plt.imshow(img)
    plt.show()

# %% [markdown]
# ### Fisheye Detector Result

# %%
for i, image in enumerate(os.listdir('./results/fisheye_detector/test_data')):
    img = plt.imread('./results/fisheye_detector/test_data/' + image)
    plt.figure(i, figsize=(4,4))
    plt.imshow(img)
    plt.show()
